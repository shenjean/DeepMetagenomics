# %%
import pandas as pd
import re

# %%
# disable chained assignments
pd.options.mode.chained_assignment = None

# %%
path_labels = '/Users/luke.thompson/deep-metagenomics/MarRef_training/MarRef.training.label.tsv'
path_kraken = '/Users/luke.thompson/deep-metagenomics/kraken2-output/MarRef.training.vs.standard.paired.kraken'

# %%
df_labels = pd.read_csv(path_labels, sep='\t', index_col=0, dtype='str')
dict_labels = dict(zip(df_labels.Training_Label, df_labels.Species))

# %%
df_kraken = pd.read_csv(path_kraken, sep='\t', header=None)
df_kraken.columns =['classified', 'sequence_id', 'taxonomy_id', 'length_bp', 'kmer_mapping']

# %%
classified_vc = df_kraken.classified.value_counts()
classified_proportion = classified_vc['C']/classified_vc.sum()
print('classified: %s/%s (%s)' % (classified_vc['C'], 
                                  classified_vc.sum(),
                                  classified_proportion))
# Out:
# classified: 7174271/7432328 (0.9652791157763758)

# %%
df_kraken_classfied = df_kraken[df_kraken.classified == 'C']

# %%
df_kraken_classfied['predicted_strain'] = [re.sub(r'(.*) \(taxid.*\)', r'\1', x) for x in df_kraken_classfied.taxonomy_id]
df_kraken_classfied['predicted_species_clean'] = [' '.join(re.sub(r'Candidatus ', '', x).split(' ')[0:2]) for x in df_kraken_classfied.predicted_strain]
df_kraken_classfied['predicted_genus_clean'] = [x.split(' ')[0] for x in df_kraken_classfied.predicted_species_clean]

# %%
df_kraken_classfied['true_label'] = [seqid.split('|')[1] for seqid in df_kraken_classfied.sequence_id]

# %%
df_kraken_classfied['true_species'] = [dict_labels[x] for x in df_kraken_classfied.true_label]
df_kraken_classfied['true_species_clean'] = [re.sub(r'_\w+', '', x) for x in df_kraken_classfied.true_species]
df_kraken_classfied['true_genus_clean'] = [x.split(' ')[0] for x in df_kraken_classfied.true_species_clean]

# %%
df_kraken_classfied['match_genus'] = (df_kraken_classfied.predicted_genus_clean == df_kraken_classfied.true_genus_clean)
df_kraken_classfied['match_species'] = (df_kraken_classfied.predicted_species_clean == df_kraken_classfied.true_species_clean)

# %%
match_genus_vc = df_kraken_classfied.match_genus.value_counts()
match_genus_proportion = match_genus_vc[True]/match_genus_vc.sum()
print('match genus: %s/%s' % (match_genus_vc[True], 
                              match_genus_vc.sum()))
print('proportion of classified: %s' % match_genus_proportion)
print('proportion of all reads: %s' % (match_genus_proportion * classified_proportion))
# Out:
# match genus: 5588605/7174271
# proportion of classified: 0.778978797985189
# proportion of all reads: 0.7519319653276874

# %%
match_species_vc = df_kraken_classfied.match_species.value_counts()
match_species_proportion = match_species_vc[True]/match_species_vc.sum()
print('match species: %s/%s' % (match_species_vc[True], 
                              match_species_vc.sum()))
print('proportion of classified: %s' % match_species_proportion)
print('proportion of all reads: %s' % (match_species_proportion * classified_proportion))
# Out:
# match species: 3690136/7174271
# proportion of classified: 0.5143569290872898
# proportion of all reads: 0.49649800170283115

# %%
df_kraken_classfied[df_kraken_classfied.match_genus == False]
# Out:
#         classified                 sequence_id  \
# 662              C  label|286|MMP00000031-8676
# 3673             C  label|286|MMP00000031-2654
# 5793             C  label|863|MMP00000346-8414
# 6266             C  label|863|MMP00000346-7468
# 8823             C  label|863|MMP00000346-2354
# ...            ...                         ...
# 7431078          C   label|543|MMP5137566-2500
# 7431485          C   label|543|MMP5137566-1686
# 7431499          C   label|543|MMP5137566-1658
# 7432005          C    label|543|MMP5137566-646
# 7432261          C    label|543|MMP5137566-134
#
#                                        taxonomy_id length_bp  \
# 662                      Homo sapiens (taxid 9606)   146|128
# 3673     Aliarcobacter cryaerophilus (taxid 28198)   124|125
# 5793               Flavobacteriaceae (taxid 49546)    82|117
# 6266               Flavobacteriaceae (taxid 49546)   104|110
# 8823               Flavobacteriaceae (taxid 49546)   113|139
# ...                                            ...       ...
# 7431078                Proteobacteria (taxid 1224)   103|113
# 7431485                Proteobacteria (taxid 1224)   110|133
# 7431499                Proteobacteria (taxid 1224)    85|115
# 7432005           Gammaproteobacteria (taxid 1236)   146|118
# 7432261                Proteobacteria (taxid 1224)     80|83
#
#                                               kmer_mapping  \
# 662                  0:64 9606:4 0:27 9606:5 0:12 |:| 0:94
# 3673               0:87 426368:1 0:2 |:| 0:39 28198:4 0:48
# 5793     2:48 |:| 49546:5 976:3 68336:4 49546:2 976:5 4...
# 6266     2:5 49546:4 2:5 49546:3 2:5 49546:4 2:18 49546...
# 8823     49546:13 2:66 |:| 2:18 200644:4 2:5 200644:8 9...
# ...                                                    ...
# 7431078        1224:12 0:26 1224:1 0:4 1224:26 |:| 1224:79
# 7431485  1224:2 2:2 1224:6 2:4 1224:46 2:5 1224:11 |:| ...
# 7431499                                1224:51 |:| 1224:81
# 7432005  1236:4 0:27 1224:2 1236:18 0:16 1236:3 0:12 12...
# 7432261                            1224:46 |:| 0:9 1224:40
#
#                     predicted_strain      predicted_species_clean  \
# 662                     Homo sapiens                 Homo sapiens
# 3673     Aliarcobacter cryaerophilus  Aliarcobacter cryaerophilus
# 5793               Flavobacteriaceae            Flavobacteriaceae
# 6266               Flavobacteriaceae            Flavobacteriaceae
# 8823               Flavobacteriaceae            Flavobacteriaceae
# ...                              ...                          ...
# 7431078               Proteobacteria               Proteobacteria
# 7431485               Proteobacteria               Proteobacteria
# 7431499               Proteobacteria               Proteobacteria
# 7432005          Gammaproteobacteria          Gammaproteobacteria
# 7432261               Proteobacteria               Proteobacteria
#
#         predicted_genus_clean true_label                 true_species  \
# 662                      Homo        286  Methanococcus maripaludis_A
# 3673            Aliarcobacter        286  Methanococcus maripaludis_A
# 5793        Flavobacteriaceae        863  Winogradskyella sp000828715
# 6266        Flavobacteriaceae        863  Winogradskyella sp000828715
# 8823        Flavobacteriaceae        863  Winogradskyella sp000828715
# ...                       ...        ...                          ...
# 7431078        Proteobacteria        543      Pseudomonas_E marincola
# 7431485        Proteobacteria        543      Pseudomonas_E marincola
# 7431499        Proteobacteria        543      Pseudomonas_E marincola
# 7432005   Gammaproteobacteria        543      Pseudomonas_E marincola
# 7432261        Proteobacteria        543      Pseudomonas_E marincola
#
#                   true_species_clean true_genus_clean  match_genus  \
# 662        Methanococcus maripaludis    Methanococcus        False
# 3673       Methanococcus maripaludis    Methanococcus        False
# 5793     Winogradskyella sp000828715  Winogradskyella        False
# 6266     Winogradskyella sp000828715  Winogradskyella        False
# 8823     Winogradskyella sp000828715  Winogradskyella        False
# ...                              ...              ...          ...
# 7431078        Pseudomonas marincola      Pseudomonas        False
# 7431485        Pseudomonas marincola      Pseudomonas        False
# 7431499        Pseudomonas marincola      Pseudomonas        False
# 7432005        Pseudomonas marincola      Pseudomonas        False
# 7432261        Pseudomonas marincola      Pseudomonas        False
#
#          match_species
# 662              False
# 3673             False
# 5793             False
# 6266             False
# 8823             False
# ...                ...
# 7431078          False
# 7431485          False
# 7431499          False
# 7432005          False
# 7432261          False
#
# [1585666 rows x 14 columns]

# %%
df_kraken_classfied[df_kraken_classfied.match_species == False]
# Out:
#         classified                 sequence_id  \
# 629              C  label|286|MMP00000031-8742
# 662              C  label|286|MMP00000031-8676
# 1592             C  label|286|MMP00000031-6816
# 3325             C  label|286|MMP00000031-3350
# 3673             C  label|286|MMP00000031-2654
# ...            ...                         ...
# 7432041          C    label|543|MMP5137566-574
# 7432093          C    label|543|MMP5137566-470
# 7432158          C    label|543|MMP5137566-340
# 7432230          C    label|543|MMP5137566-196
# 7432261          C    label|543|MMP5137566-134
#
#                                        taxonomy_id length_bp  \
# 629                     Methanococcus (taxid 2184)     83|91
# 662                      Homo sapiens (taxid 9606)   146|128
# 1592                    Methanococcus (taxid 2184)    87|149
# 3325                    Methanococcus (taxid 2184)   112|125
# 3673     Aliarcobacter cryaerophilus (taxid 28198)   124|125
# ...                                            ...       ...
# 7432041                    Pseudomonas (taxid 286)   127|105
# 7432093                    Pseudomonas (taxid 286)   127|103
# 7432158                    Pseudomonas (taxid 286)   111|102
# 7432230                    Pseudomonas (taxid 286)     78|91
# 7432261                Proteobacteria (taxid 1224)     80|83
#
#                                               kmer_mapping  \
# 629      2182:2 28890:3 131567:5 28890:3 2182:10 2184:2...
# 662                  0:64 9606:4 0:27 9606:5 0:12 |:| 0:94
# 1592     2184:14 2183:34 2182:5 |:| 2183:31 2184:5 2183...
# 3325     2184:25 2182:5 28890:2 2283794:10 131567:4 218...
# 3673               0:87 426368:1 0:2 |:| 0:39 28198:4 0:48
# ...                                                    ...
# 7432041                                  286:93 |:| 286:71
# 7432093  1236:1 1224:12 1236:3 1224:7 2:9 1224:14 2:18 ...
# 7432158     1236:1 286:76 |:| 286:32 0:10 286:5 0:18 286:3
# 7432230                                  286:44 |:| 286:57
# 7432261                            1224:46 |:| 0:9 1224:40
#
#                     predicted_strain      predicted_species_clean  \
# 629                    Methanococcus                Methanococcus
# 662                     Homo sapiens                 Homo sapiens
# 1592                   Methanococcus                Methanococcus
# 3325                   Methanococcus                Methanococcus
# 3673     Aliarcobacter cryaerophilus  Aliarcobacter cryaerophilus
# ...                              ...                          ...
# 7432041                  Pseudomonas                  Pseudomonas
# 7432093                  Pseudomonas                  Pseudomonas
# 7432158                  Pseudomonas                  Pseudomonas
# 7432230                  Pseudomonas                  Pseudomonas
# 7432261               Proteobacteria               Proteobacteria
#
#         predicted_genus_clean true_label                 true_species  \
# 629             Methanococcus        286  Methanococcus maripaludis_A
# 662                      Homo        286  Methanococcus maripaludis_A
# 1592            Methanococcus        286  Methanococcus maripaludis_A
# 3325            Methanococcus        286  Methanococcus maripaludis_A
# 3673            Aliarcobacter        286  Methanococcus maripaludis_A
# ...                       ...        ...                          ...
# 7432041           Pseudomonas        543      Pseudomonas_E marincola
# 7432093           Pseudomonas        543      Pseudomonas_E marincola
# 7432158           Pseudomonas        543      Pseudomonas_E marincola
# 7432230           Pseudomonas        543      Pseudomonas_E marincola
# 7432261        Proteobacteria        543      Pseudomonas_E marincola
#
#                 true_species_clean true_genus_clean  match_genus  \
# 629      Methanococcus maripaludis    Methanococcus         True
# 662      Methanococcus maripaludis    Methanococcus        False
# 1592     Methanococcus maripaludis    Methanococcus         True
# 3325     Methanococcus maripaludis    Methanococcus         True
# 3673     Methanococcus maripaludis    Methanococcus        False
# ...                            ...              ...          ...
# 7432041      Pseudomonas marincola      Pseudomonas         True
# 7432093      Pseudomonas marincola      Pseudomonas         True
# 7432158      Pseudomonas marincola      Pseudomonas         True
# 7432230      Pseudomonas marincola      Pseudomonas         True
# 7432261      Pseudomonas marincola      Pseudomonas        False
#
#          match_species
# 629              False
# 662              False
# 1592             False
# 3325             False
# 3673             False
# ...                ...
# 7432041          False
# 7432093          False
# 7432158          False
# 7432230          False
# 7432261          False
#
# [3484135 rows x 14 columns]

# %%
df_kraken_classfied.head()
# Out:
#   classified                  sequence_id  \
# 0          C  label|286|MMP00000031-10000
# 1          C   label|286|MMP00000031-9998
# 2          C   label|286|MMP00000031-9996
# 3          C   label|286|MMP00000031-9994
# 4          C   label|286|MMP00000031-9992
#
#                                    taxonomy_id length_bp  \
# 0  Methanococcus maripaludis C7 (taxid 426368)    129|88
# 1  Methanococcus maripaludis C7 (taxid 426368)   109|149
# 2  Methanococcus maripaludis C7 (taxid 426368)   106|100
# 3  Methanococcus maripaludis C7 (taxid 426368)   110|101
# 4  Methanococcus maripaludis C7 (taxid 426368)   110|124
#
#                                         kmer_mapping  \
# 0  426368:17 2184:2 39152:5 426368:13 39152:1 426...
# 1  39152:7 426368:12 39152:12 0:7 426368:3 0:5 42...
# 2  0:54 402880:2 0:16 |:| 426368:55 39152:7 426368:4
# 3  426368:76 |:| 2184:1 39152:7 2184:1 2182:7 402...
# 4  39152:21 426368:35 39152:5 426368:15 |:| 42636...
#
#                predicted_strain    predicted_species_clean  \
# 0  Methanococcus maripaludis C7  Methanococcus maripaludis
# 1  Methanococcus maripaludis C7  Methanococcus maripaludis
# 2  Methanococcus maripaludis C7  Methanococcus maripaludis
# 3  Methanococcus maripaludis C7  Methanococcus maripaludis
# 4  Methanococcus maripaludis C7  Methanococcus maripaludis
#
#   predicted_genus_clean true_label                 true_species  \
# 0         Methanococcus        286  Methanococcus maripaludis_A
# 1         Methanococcus        286  Methanococcus maripaludis_A
# 2         Methanococcus        286  Methanococcus maripaludis_A
# 3         Methanococcus        286  Methanococcus maripaludis_A
# 4         Methanococcus        286  Methanococcus maripaludis_A
#
#           true_species_clean true_genus_clean  match_genus  match_species
# 0  Methanococcus maripaludis    Methanococcus         True           True
# 1  Methanococcus maripaludis    Methanococcus         True           True
# 2  Methanococcus maripaludis    Methanococcus         True           True
# 3  Methanococcus maripaludis    Methanococcus         True           True
# 4  Methanococcus maripaludis    Methanococcus         True           True

# %% [raw]
# # get rows matching a substring in taxonomy_id
# df_kraken_classfied[[x.find('Candidatus')>-1 for x in df_kraken_classfied.taxonomy_id]]

# %% [raw]
# # get small subset to work with
# df_kraken_short = df_kraken_classfied.iloc[:100000:1000,:]

# %% [raw]
# df_kraken_short
